# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Patdeep.csv")

# %%
print(df.head())
# Out:
#       Song Name   P(S)=X1  P(r )=X2   P(R)=X3   P(g)=X4  P(G)=X5   P(M)=X6  \
# 0  Raag Patdeep  0.171429         0  0.042857  0.114286        0  0.085714
#
#    P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0        0  0.228571        0  0.114286         0  0.242857

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="orange")
